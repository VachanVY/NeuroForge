# %% [markdown]
# # Train MLP for MNIST Dataset!!!

# %%
import typing as tp
import time

import torch # [for torch.tensor(...) {instead of numpy}]
import torchvision # for mnist dataset
from torch import Tensor # for type hints
import matplotlib.pyplot as plt
DEVICE = torch.device("cpu")
g = torch.Generator(device=DEVICE).manual_seed(42)

# %% [markdown]
# ## Get Dataset

# %%
trainset = torchvision.datasets.MNIST(root='./data', train=True, download=True)
train_data = trainset.data.float()
y_train = trainset.targets

testset = torchvision.datasets.MNIST(root='./data', train=False, download=True)
X_VAL = testset.data.float()
y_val = testset.targets

# %%
X_train = train_data.reshape((-1, 28*28))/255.
X_val = X_VAL.reshape((-1, 28*28))/255.

num_classes = torch.unique(y_train)
print(f"X_train.shape = {X_train.shape}\ny_train.shape = {y_train.shape}\nX_val.shape = {X_val.shape}\ny_val.shape = {y_val.shape}")
# Out:
# X_train.shape = torch.Size([60000, 784])
# y_train.shape = torch.Size([60000])
# X_val.shape = torch.Size([10000, 784])
# y_val.shape = torch.Size([10000])

# %% [markdown]
# ## MLP-TODO:
# * Initialize parameters
# * Make minibatches
# * Define Activation functions and Loss function
# * Forward Pass
# * Backward Pass: Compute grads (Will be using torch's autograd as you are a BackpropWhiz, see `nn.ipynb` notebook if you haven't)
# * Update parameters using gradient descent
# * `for` loop for epochs

# %% [markdown]
# ### Initialize parameters

# %%
def initialize_params(size:tp.Sequence): # [0:784, 1:576, 2:512, 3:128, 4:10]
    """returns `parmas` (parameters)"""
    # input layer (784, 576)
    w1 = torch.randn((size[0], size[1]), generator=g, device=DEVICE)*(2./size[0])**0.5
    b1 = torch.randn(size[1], generator=g, device=DEVICE)*0.001

    # hidden layer 1 (576, 512)
    w2 = torch.randn((size[1], size[2]), generator=g, device=DEVICE)*(2./size[1])**0.5
    b2 = torch.randn(size[2], generator=g, device=DEVICE)*0.009

    # hidden layer 2 (512, 128)
    w3 = torch.randn((size[2], size[3]), generator=g, device=DEVICE)*(2./size[2])**0.5
    b3 = torch.randn(size[3], generator=g, device=DEVICE)*0.008

    # output layer (128, 10)
    w4 = torch.randn((size[3], size[4]), generator=g, device=DEVICE)*(2./size[3])**0.5
    b4 = torch.randn(size[4], generator=g, device=DEVICE)*0.00109

    params:list[Tensor] = [w1, b1, w2, b2, w3, b3, w4, b4]
    print("Number of parameters in the network:", sum(p.nelement() for p in params))
    
    for p in params:
        p.requires_grad = True
    return params

# %% [markdown]
# ### Make minibatches

# %%
def shuffle(X:Tensor, y:Tensor): # (m, ...), (m, ...)
    """returns X, y (but shuffled)"""
    idx = torch.randperm(X.shape[0])
    return X[idx].to(DEVICE), y[idx].to(DEVICE)

# %%
def batch(X:Tensor, y:Tensor, batch_size:int):
    """returns X, y (batched form of inputs X and y)"""
    num_features = X.shape[-1]
    rem_idx = None
    if len(X)%batch_size != 0:
        rem_idx = -(len(X)%batch_size)
    X, y = shuffle(X, y) # (m, 784), (m, 10)
    X, y = X[:rem_idx], y[:rem_idx]
    X, y = X[None].reshape((-1, batch_size, num_features)), y[None].reshape((-1, batch_size))
    return X.to(device=DEVICE), y.to(device=DEVICE) # (m//B, B, 784), (m//B, B, 10)

# %% [markdown]
# ## Dropout

# %%
def dropout(x:Tensor, keep_prob:float, training:bool):
    if keep_prob == 1.0 or not training:
        return x
    if keep_prob == 0.0:
        return torch.zeros_like(x, device=x.device)
    
    mask = torch.bernoulli(torch.full_like(x, keep_prob, device=x.device), generator=g).bool()
    return torch.where(mask, x/keep_prob, 0.0)

# %% [markdown]
# ### Define Activation function and Cross Entropy

# %%
def relu(x:Tensor):
    return x * (x > 0)

# %%
def softmax(logits:Tensor, axis:int=-1):
    logits = logits - logits.max(axis, keepdim=True).values # (B, 10)
    exp = logits.exp() # (B, 10)
    exp_sum = exp.sum(axis, keepdim=True) # (B, 1)
    return exp/exp_sum # (B, 10)

# %%
def CrossEntropy(y_true:Tensor, y_proba:Tensor):
    log_probs = y_proba.log() # (B, num_classes)
    L = -log_probs[range(len(y_proba)), y_true].mean() # ()
    return L # ()

# %%
def dropout(x:Tensor, keep_prob:float, training:bool):
    if keep_prob == 1.0 or not training:
        return x
    if keep_prob == 0.0:
        return torch.zeros_like(x, device=x.device)
    
    mask = torch.bernoulli(torch.full_like(x, keep_prob, device=x.device), generator=g).bool()
    return torch.where(mask, x/keep_prob, 0.0)

# %% [markdown]
# ### Forward Propagation

# %%
def forwardprop(
    x:Tensor, 
    y:Tensor, 
    params:list[Tensor],
    training:bool
): # [784, 576, 512, 128, 10]
    """ returns `loss(x, y)`, `y_proba`, `params`"""
    w1, b1, w2, b2, w3, b3, w4, b4 = params
    
    z1 = x.float().to(DEVICE) @ w1 + b1 # (B, 576) <== (B, 784) @ (784, 576) + (512)
    z1 = dropout(z1, keep_prob=0.8, training=training)
    h1 = relu(z1) # (B, 576)

    z2 = h1 @ w2 + b2 # (B, 512) <== (B, 576) @ (576, 512) + (512)
    z2 = dropout(z2, keep_prob=0.5, training=training)
    h2 = relu(z2) # (B, 512)

    z3 = h2 @ w3 + b3 # (B, 128) <== (B, 512) @ (512, 128)
    z3 = dropout(z3, keep_prob=0.5, training=training)
    h3 = relu(z3) # (B, 128)

    logits = h3 @ w4 + b4 # (B, 10) <== (B, 128) @ (128, 10)
    y_proba = softmax(logits) # (B, 10)
    loss = CrossEntropy(y, y_proba) # ()

    params = [w1, b1, w2, b2, w3, b3, w4, b4]
    return loss, y_proba, params #, activations

# %% [markdown]
# ### BackPropagation
# * Skipping this as you are a BackpropWhiz! (See nn.ipynb for that if you haven't)

# %% [markdown]
# ### Gradient Descent

# %%
def zero_grads(params:list[Tensor]):
    for param in params:
        param.grad = None

def sgd(lr:float, params:list[Tensor]):
    """returns updated `params` (parameters)"""
    for param in params:
        param.data -= lr * param.grad
    return params

# %% [markdown]
# ### Train Loop

# %%
def get_accuracy(y_true:Tensor, y_probs:Tensor):
    y_pred = torch.argmax(y_probs, axis=-1).cpu()
    return (y_true.cpu()==y_pred).float().sum()/len(y_true)

# %%
def train_loop(
        lr,
        epochs,
        train_ds, 
        val_ds,
        batch_size = 32,
        val_interval = 2
    ):
    X_train, y_train = train_ds
    XB_train, yB_train = batch(X_train, y_train, batch_size); m_B = XB_train.shape[0]
    X_val, y_val = val_ds
    
    # initialize parameters
    size = [784, 576, 512, 128, 10]
    params = initialize_params(size)

    # For loop for epochs and steps
    plotlosses = []; t0 = time.time()
    for epoch in range(epochs):
        print(f"Epoch: {epoch+1}/{epochs}", end=" | ")
        losses = 0
        XB_train, yB_train = shuffle(XB_train, yB_train)
        for step in range(m_B):
            # Get batch
            X_batch, y_batch = XB_train[step].to(DEVICE), yB_train[step].to(DEVICE)
            # Forward pass
            loss, y_proba, params = forwardprop(
                X_batch, y_batch, params, training=True
            ); losses += loss
            # Zero grads
            zero_grads(params)
            # Backward pass
            loss.backward()
            assert not torch.isnan(loss).any()
            # Update params
            params = sgd(lr, params)
            # list of losses for plotting
            plotlosses.append(loss.item())
        # time
        t1 = time.time()
        dt = t1 - t0; t0 = t1
        print(f"Loss: {(losses/m_B):.4f}", end=f" | Avg time per step: {(dt*1000/m_B):.2f} ms | ")
        print(f"Validation Loss: {forwardprop(X_val, y_val, params, False)[0]:.4f} |" if (epoch%val_interval==0 or epoch==epochs-1) else "")
    
    train_metrics = forwardprop(X_train, y_train, params, False)
    val_metrics = forwardprop(X_val, y_val, params, False)
    print(f"Train Accuracy:      {get_accuracy(y_train, train_metrics[1]):.4f} | Train Loss: {train_metrics[0]:.4f} |")
    print(f"Validation Accuracy: {get_accuracy(y_val, val_metrics[1]):.4f} | Validation Loss: {val_metrics[0]:.4f} |")
    return params, plotlosses

# %%
params, losses = train_loop(0.01, 50, [X_train, y_train], [X_val, y_val], val_interval=1)
plt.plot(losses)
plt.xlabel("Steps")
plt.ylabel("Loss")
plt.title("`dropout_scale.ipynb`")
plt.show()
# Out:
# Number of parameters in the network: 814538
# Epoch: 1/50 | Loss: 0.8868 | Avg time per step: 1.18 ms | Validation Loss: 0.2930 |
# Epoch: 2/50 | Loss: 0.4244 | Avg time per step: 1.17 ms | Validation Loss: 0.2203 |
# Epoch: 3/50 | Loss: 0.3238 | Avg time per step: 1.15 ms | Validation Loss: 0.1766 |
# Epoch: 4/50 | Loss: 0.2709 | Avg time per step: 1.14 ms | Validation Loss: 0.1552 |
# Epoch: 5/50 | Loss: 0.2355 | Avg time per step: 1.16 ms | Validation Loss: 0.1410 |
# Epoch: 6/50 | Loss: 0.2089 | Avg time per step: 1.14 ms | Validation Loss: 0.1254 |
# Epoch: 7/50 | Loss: 0.1919 | Avg time per step: 1.15 ms | Validation Loss: 0.1194 |
# Epoch: 8/50 | Loss: 0.1730 | Avg time per step: 1.17 ms | Validation Loss: 0.1096 |
# Epoch: 9/50 | Loss: 0.1594 | Avg time per step: 1.15 ms | Validation Loss: 0.1024 |
# Epoch: 10/50 | Loss: 0.1505 | Avg time per step: 1.14 ms | Validation Loss: 0.0979 |
# Epoch: 11/50 | Loss: 0.1397 | Avg time per step: 1.15 ms | Validation Loss: 0.0942 |
# Epoch: 12/50 | Loss: 0.1297 | Avg time per step: 1.14 ms | Validation Loss: 0.0917 |
# Epoch: 13/50 | Loss: 0.1251 | Avg time per step: 1.15 ms | Validation Loss: 0.0859 |
# Epoch: 14/50 | Loss: 0.1154 | Avg time per step: 1.16 ms | Validation Loss: 0.0860 |
# Epoch: 15/50 | Loss: 0.1092 | Avg time per step: 1.16 ms | Validation Loss: 0.0826 |
# Epoch: 16/50 | Loss: 0.1020 | Avg time per step: 1.16 ms | Validation Loss: 0.0797 |
# Epoch: 17/50 | Loss: 0.0972 | Avg time per step: 1.16 ms | Validation Loss: 0.0791 |
# Epoch: 18/50 | Loss: 0.0918 | Avg time per step: 1.16 ms | Validation Loss: 0.0791 |
# Epoch: 19/50 | Loss: 0.0873 | Avg time per step: 1.15 ms | Validation Loss: 0.0752 |
# Epoch: 20/50 | Loss: 0.0858 | Avg time per step: 1.15 ms | Validation Loss: 0.0719 |
# Epoch: 21/50 | Loss: 0.0796 | Avg time per step: 1.16 ms | Validation Loss: 0.0735 |
# Epoch: 22/50 | Loss: 0.0778 | Avg time per step: 1.17 ms | Validation Loss: 0.0719 |
# Epoch: 23/50 | Loss: 0.0730 | Avg time per step: 1.15 ms | Validation Loss: 0.0708 |
# Epoch: 24/50 | Loss: 0.0694 | Avg time per step: 1.15 ms | Validation Loss: 0.0706 |
# Epoch: 25/50 | Loss: 0.0675 | Avg time per step: 1.15 ms | Validation Loss: 0.0675 |
# Epoch: 26/50 | Loss: 0.0635 | Avg time per step: 1.17 ms | Validation Loss: 0.0687 |
# Epoch: 27/50 | Loss: 0.0600 | Avg time per step: 1.17 ms | Validation Loss: 0.0673 |
# Epoch: 28/50 | Loss: 0.0579 | Avg time per step: 1.16 ms | Validation Loss: 0.0676 |
# Epoch: 29/50 | Loss: 0.0564 | Avg time per step: 1.16 ms | Validation Loss: 0.0675 |
# Epoch: 30/50 | Loss: 0.0539 | Avg time per step: 1.17 ms | Validation Loss: 0.0660 |
# Epoch: 31/50 | Loss: 0.0528 | Avg time per step: 1.16 ms | Validation Loss: 0.0679 |
# Epoch: 32/50 | Loss: 0.0530 | Avg time per step: 1.16 ms | Validation Loss: 0.0667 |
# Epoch: 33/50 | Loss: 0.0489 | Avg time per step: 1.16 ms | Validation Loss: 0.0669 |
# Epoch: 34/50 | Loss: 0.0481 | Avg time per step: 1.16 ms | Validation Loss: 0.0663 |
# Epoch: 35/50 | Loss: 0.0443 | Avg time per step: 1.21 ms | Validation Loss: 0.0669 |
# Epoch: 36/50 | Loss: 0.0434 | Avg time per step: 1.18 ms | Validation Loss: 0.0675 |
# Epoch: 37/50 | Loss: 0.0432 | Avg time per step: 1.15 ms | Validation Loss: 0.0687 |
# Epoch: 38/50 | Loss: 0.0421 | Avg time per step: 1.18 ms | Validation Loss: 0.0670 |
# Epoch: 39/50 | Loss: 0.0393 | Avg time per step: 1.16 ms | Validation Loss: 0.0668 |
# Epoch: 40/50 | Loss: 0.0381 | Avg time per step: 1.16 ms | Validation Loss: 0.0684 |
# Epoch: 41/50 | Loss: 0.0356 | Avg time per step: 1.16 ms | Validation Loss: 0.0656 |
# Epoch: 42/50 | Loss: 0.0354 | Avg time per step: 1.15 ms | Validation Loss: 0.0676 |
# Epoch: 43/50 | Loss: 0.0356 | Avg time per step: 1.17 ms | Validation Loss: 0.0653 |
# Epoch: 44/50 | Loss: 0.0348 | Avg time per step: 1.17 ms | Validation Loss: 0.0659 |
# Epoch: 45/50 | Loss: 0.0322 | Avg time per step: 1.16 ms | Validation Loss: 0.0657 |
# Epoch: 46/50 | Loss: 0.0311 | Avg time per step: 1.16 ms | Validation Loss: 0.0677 |
# Epoch: 47/50 | Loss: 0.0301 | Avg time per step: 1.16 ms | Validation Loss: 0.0680 |
# Epoch: 48/50 | Loss: 0.0283 | Avg time per step: 1.17 ms | Validation Loss: 0.0681 |
# Epoch: 49/50 | Loss: 0.0280 | Avg time per step: 1.17 ms | Validation Loss: 0.0647 |
# Epoch: 50/50 | Loss: 0.0277 | Avg time per step: 1.16 ms | Validation Loss: 0.0647 |
# Train Accuracy:      0.9991 | Train Loss: 0.0043 |
# Validation Accuracy: 0.9823 | Validation Loss: 0.0647 |

# %% [markdown]
# * The gap between training loss & accuracy and val loss & accuracy has decreased than that of in `nn_scale.ipynb`

# %% [markdown]
# ## Make Predictions

# %%
def predict(img_idx):
    img = torch.tensor(X_VAL[img_idx].tolist())[0] # (28, 28)
    y_true = y_val[img_idx].cpu()
    plt.imshow(img, cmap='gray')
    plt.axis('off')

    y_pred = torch.argmax(forwardprop(img.reshape((1, -1)), y_true, params, False)[1], axis=-1).cpu()
    print(f"True Digit: {y_true}")
    print(f"Predicted Digit: {y_pred}")
    plt.show()

# %%
for _ in range(100):
    predict(torch.randint(10_000, (1,)))
# Out:
# True Digit: tensor([6])
# Predicted Digit: tensor([6])
# True Digit: tensor([5])
# Predicted Digit: tensor([5])
# True Digit: tensor([4])
# Predicted Digit: tensor([4])
# True Digit: tensor([0])
# Predicted Digit: tensor([0])
# True Digit: tensor([0])
# Predicted Digit: tensor([0])
# True Digit: tensor([2])
# Predicted Digit: tensor([2])
# True Digit: tensor([0])
# Predicted Digit: tensor([0])
# True Digit: tensor([0])
# Predicted Digit: tensor([0])
# True Digit: tensor([0])
# Predicted Digit: tensor([0])
# True Digit: tensor([1])
# Predicted Digit: tensor([1])
# True Digit: tensor([8])
# Predicted Digit: tensor([8])
# True Digit: tensor([2])
# Predicted Digit: tensor([2])
# True Digit: tensor([4])
# Predicted Digit: tensor([4])
# True Digit: tensor([0])
# Predicted Digit: tensor([0])
# True Digit: tensor([2])
# Predicted Digit: tensor([2])
# True Digit: tensor([2])
# Predicted Digit: tensor([2])
# True Digit: tensor([3])
# Predicted Digit: tensor([3])
# True Digit: tensor([5])
# Predicted Digit: tensor([5])
# True Digit: tensor([6])
# Predicted Digit: tensor([6])
# True Digit: tensor([1])
# Predicted Digit: tensor([1])
# True Digit: tensor([2])
# Predicted Digit: tensor([2])
# True Digit: tensor([0])
# Predicted Digit: tensor([0])
# True Digit: tensor([6])
# Predicted Digit: tensor([6])
# True Digit: tensor([1])
# Predicted Digit: tensor([1])
# True Digit: tensor([0])
# Predicted Digit: tensor([0])
# True Digit: tensor([1])
# Predicted Digit: tensor([1])
# True Digit: tensor([0])
# Predicted Digit: tensor([0])
# True Digit: tensor([0])
# Predicted Digit: tensor([0])
# True Digit: tensor([0])
# Predicted Digit: tensor([0])
# True Digit: tensor([1])
# Predicted Digit: tensor([1])
# True Digit: tensor([0])
# Predicted Digit: tensor([0])
# True Digit: tensor([6])
# Predicted Digit: tensor([6])
# True Digit: tensor([9])
# Predicted Digit: tensor([9])
# True Digit: tensor([8])
# Predicted Digit: tensor([8])
# True Digit: tensor([6])
# Predicted Digit: tensor([6])
# True Digit: tensor([1])
# Predicted Digit: tensor([1])
# True Digit: tensor([2])
# Predicted Digit: tensor([2])
# True Digit: tensor([1])
# Predicted Digit: tensor([1])
# True Digit: tensor([2])
# Predicted Digit: tensor([2])
# True Digit: tensor([9])
# Predicted Digit: tensor([9])
# True Digit: tensor([7])
# Predicted Digit: tensor([7])
# True Digit: tensor([4])
# Predicted Digit: tensor([4])
# True Digit: tensor([6])
# Predicted Digit: tensor([6])
# True Digit: tensor([1])
# Predicted Digit: tensor([1])
# True Digit: tensor([8])
# Predicted Digit: tensor([8])
# True Digit: tensor([2])
# Predicted Digit: tensor([2])
# True Digit: tensor([8])
# Predicted Digit: tensor([8])
# True Digit: tensor([1])
# Predicted Digit: tensor([1])
# True Digit: tensor([1])
# Predicted Digit: tensor([1])
# True Digit: tensor([6])
# Predicted Digit: tensor([6])
# True Digit: tensor([3])
# Predicted Digit: tensor([3])
# True Digit: tensor([6])
# Predicted Digit: tensor([6])
# True Digit: tensor([8])
# Predicted Digit: tensor([8])
# True Digit: tensor([1])
# Predicted Digit: tensor([1])
# True Digit: tensor([2])
# Predicted Digit: tensor([2])
# True Digit: tensor([1])
# Predicted Digit: tensor([1])
# True Digit: tensor([8])
# Predicted Digit: tensor([8])
# True Digit: tensor([9])
# Predicted Digit: tensor([9])
# True Digit: tensor([3])
# Predicted Digit: tensor([3])
# True Digit: tensor([9])
# Predicted Digit: tensor([9])
# True Digit: tensor([8])
# Predicted Digit: tensor([8])
# True Digit: tensor([6])
# Predicted Digit: tensor([6])
# True Digit: tensor([5])
# Predicted Digit: tensor([5])
# True Digit: tensor([7])
# Predicted Digit: tensor([7])
# True Digit: tensor([5])
# Predicted Digit: tensor([5])
# True Digit: tensor([1])
# Predicted Digit: tensor([1])
# True Digit: tensor([2])
# Predicted Digit: tensor([2])
# True Digit: tensor([9])
# Predicted Digit: tensor([9])
# True Digit: tensor([7])
# Predicted Digit: tensor([7])
# True Digit: tensor([2])
# Predicted Digit: tensor([2])
# True Digit: tensor([1])
# Predicted Digit: tensor([1])
# True Digit: tensor([0])
# Predicted Digit: tensor([0])
# True Digit: tensor([9])
# Predicted Digit: tensor([9])
# True Digit: tensor([1])
# Predicted Digit: tensor([1])
# True Digit: tensor([6])
# Predicted Digit: tensor([6])
# True Digit: tensor([2])
# Predicted Digit: tensor([2])
# True Digit: tensor([5])
# Predicted Digit: tensor([5])
# True Digit: tensor([6])
# Predicted Digit: tensor([6])
# True Digit: tensor([2])
# Predicted Digit: tensor([2])
# True Digit: tensor([0])
# Predicted Digit: tensor([0])
# True Digit: tensor([2])
# Predicted Digit: tensor([2])
# True Digit: tensor([3])
# Predicted Digit: tensor([3])
# True Digit: tensor([0])
# Predicted Digit: tensor([0])
# True Digit: tensor([3])
# Predicted Digit: tensor([3])
# True Digit: tensor([0])
# Predicted Digit: tensor([0])
# True Digit: tensor([9])
# Predicted Digit: tensor([9])
# True Digit: tensor([8])
# Predicted Digit: tensor([8])
# True Digit: tensor([6])
# Predicted Digit: tensor([6])
# True Digit: tensor([4])
# Predicted Digit: tensor([4])
# True Digit: tensor([0])
# Predicted Digit: tensor([0])
# True Digit: tensor([2])
# Predicted Digit: tensor([2])
# True Digit: tensor([1])
# Predicted Digit: tensor([1])
# True Digit: tensor([3])
# Predicted Digit: tensor([3])
# True Digit: tensor([3])
# Predicted Digit: tensor([2])
# True Digit: tensor([3])
# Predicted Digit: tensor([3])
# True Digit: tensor([1])
# Predicted Digit: tensor([1])
# True Digit: tensor([3])
# Predicted Digit: tensor([3])
# True Digit: tensor([9])
# Predicted Digit: tensor([9])
# True Digit: tensor([3])
# Predicted Digit: tensor([3])
# True Digit: tensor([9])
# Predicted Digit: tensor([9])

# %%
# def dropout(x:Tensor, keep_prob:float, training:bool):
#     if keep_prob == 1.0 or not training:
#         return x
#     if keep_prob == 0.0:
#         return torch.zeros_like(x, device=x.device)
    
#     mask = torch.bernoulli(torch.full_like(x, keep_prob, device=x.device), generator=g).bool()
#     return torch.where(mask, x/keep_prob, 0.0)

# def assert_func(exp, statememt):
#     assert exp, statememt

# torch_dropout = torch.nn.Dropout(0.5)

# def check_expectation_dropout(shape:tuple, keep_prob:float=0.5, torch_func=False):
#     x = torch.rand(shape, dtype=torch.float32) # (B, D)
#     if torch_func:
#         drop_x = torch.stack([torch_dropout(xi) for xi in x], dim=0)
#     else:
#         drop_x = torch.stack([dropout(xi, keep_prob, training=True) for xi in x], dim=0)
#     expect_x, expect_dropx = x.mean(0), drop_x.mean(0)
#     print("(expect_x-expect_dropx).abs().mean(0)", (expect_x-expect_dropx).abs().mean(0), sep="\n")
#     return x, drop_x

# x, dx = check_expectation_dropout((40000, 1000), 0.1, torch_func=True)
# x.shape, dx.shape

# x, dx = check_expectation_dropout((40000, 1000), 0.1, torch_func=False)
# x.shape, dx.shape
