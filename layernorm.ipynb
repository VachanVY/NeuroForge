# %% [markdown]
# # Train MLP for MNIST Dataset!!!

# %%
import typing as tp
import os
import time

import torch #[for torch.tensor(...) {instead of numpy}]
import torchvision # for mnist dataset
from torch import Tensor # for type hints
import matplotlib.pyplot as plt
DEVICE = torch.device("cpu")
g = torch.Generator(device=DEVICE).manual_seed(42)

# %% [markdown]
# ## Get Dataset

# %%
trainset = torchvision.datasets.MNIST(root='./data', train=True, download=True)
train_data = trainset.data.float()
y_train = trainset.targets

testset = torchvision.datasets.MNIST(root='./data', train=False, download=True)
X_VAL = testset.data.float()
y_val = testset.targets

# %%
X_train = train_data.reshape((-1, 28*28))/255.
X_val = X_VAL.reshape((-1, 28*28))/255.

num_classes = torch.unique(y_train)
print(f"X_train.shape = {X_train.shape}\ny_train.shape = {y_train.shape}\nX_val.shape = {X_val.shape}\ny_val.shape = {y_val.shape}")
# Out:
# X_train.shape = torch.Size([60000, 784])
# y_train.shape = torch.Size([60000])
# X_val.shape = torch.Size([10000, 784])
# y_val.shape = torch.Size([10000])

# %% [markdown]
# ## MLP-TODO:
# * Initialize parameters
# * Make minibatches
# * Define Activation functions and Loss function
# * Forward Pass
# * Backward Pass: Compute grads (Will be using torch's autograd as you are a BackpropWhiz, see `nn.ipynb` notebook if you haven't)
# * Update parameters using gradient descent
# * `for` loop for epochs

# %% [markdown]
# ### Initialize parameters

# %%
def initialize_params(size:tp.Sequence): # [784, 512, 128, 10]
    """returns `parmas` (parameters)"""
    # input layer
    w1 = torch.randn((size[0], size[1]), generator=g, device=DEVICE)*(2./size[0])**0.5
    b1 = torch.randn(size[1], generator=g, device=DEVICE)*0.01
    gamma1 = torch.ones((1, size[1]), device=DEVICE)
    beta1 = torch.zeros((1, size[1]), device=DEVICE)

    # hidden layer 1
    w2 = torch.randn((size[1], size[2]), generator=g, device=DEVICE)*(2./size[1])**0.5
    b2 = torch.randn(size[2], generator=g, device=DEVICE)*0.009
    gamma2 = torch.ones((1, size[2]), device=DEVICE)
    beta2 = torch.zeros((1, size[2]), device=DEVICE)

    # output layer
    w3 = torch.randn((size[2], size[3]), generator=g, device=DEVICE)*(2./size[2])**0.5
    b3 = torch.randn(size[3], generator=g, device=DEVICE)*0.0109

    params:list[Tensor] = [w1, b1, gamma1, beta1, w2, b2, gamma2, beta2, w3, b3]
    print("Number of parameters in the network:", sum(p.nelement() for p in params))
    
    for p in params:
        p.requires_grad = True
    return params

# %% [markdown]
# ### Make minibatches

# %%
def shuffle(X:Tensor, y:Tensor): # (m, ...), (m, ...)
    """returns X, y (but shuffled)"""
    idx = torch.randperm(X.shape[0])
    return X[idx].to(DEVICE), y[idx].to(DEVICE)

# %%
def batch(X:Tensor, y:Tensor, batch_size:int):
    """returns X, y (batched form of inputs X and y)"""
    num_features = X.shape[-1]
    rem_idx = None
    if len(X)%batch_size != 0:
        rem_idx = -(len(X)%batch_size)
    X, y = shuffle(X, y) # (m, 784), (m, 10)
    X, y = X[:rem_idx], y[:rem_idx]
    X, y = X[None].reshape((-1, batch_size, num_features)), y[None].reshape((-1, batch_size))
    return X.to(device=DEVICE), y.to(device=DEVICE) # (m//B, B, 784), (m//B, B, 10)

# %% [markdown]
# ### Define Activation function and Cross Entropy

# %%
def relu(x:Tensor):
    return x * (x > 0)

# %%
def softmax(logits:Tensor, axis:int=-1):
    logits = logits - logits.max(axis, keepdim=True).values # (B, 10)
    exp = logits.exp() # (B, 10)
    exp_sum = exp.sum(axis, keepdim=True) # (B, 1)
    return exp/exp_sum # (B, 10)

# %%
def CrossEntropy(y_true:Tensor, y_proba:Tensor):
    log_probs = y_proba.log() # (B, num_classes)
    L = -log_probs[range(len(y_proba)), y_true].mean() # ()
    return L # ()

# %%
def layernorm(
    inputs:Tensor, # (B, num_features)
    gamma:Tensor,  # (1, num_features)
    beta:Tensor,   # (1, num_features)
):
    # compute mean and variance along the feature dimension
    mean = inputs.mean(axis=-1, keepdim=True) # (B, 1)
    var = inputs.var(axis=-1, keepdim=True)   # (B, 1)

    # compute norm and normalize the inputs
    norm = (inputs - mean) / (var + 1e-5)**0.5
    return gamma * norm + beta

# %% [markdown]
# ### Forward Propagation

# %%
def forwardprop(
    x:Tensor, 
    y:Tensor, 
    params:list[Tensor],
): # [784, 512, 128, 10]
    """ returns `loss(x, y)`, `y_proba`, `params`, `activations` """
    w1, b1, gamma1, beta1, w2, b2, gamma2, beta2, w3, b3 = params
    
    z1 = x.float().to(DEVICE) @ w1 + b1 # (B, 512) <== (B, 784) @ (784, 512) + (512)
    h1 = relu(z1) # (B, 512)
    bnh1 = layernorm(h1, gamma1, beta1) # (B, 512)

    z2 = bnh1 @ w2 + b2 # (B, 128) <== (B, 512) @ (512, 128)
    h2 = relu(z2) # (B, 128)
    bnh2 = layernorm(h2, gamma2, beta2) # (B, 128)

    logits = bnh2 @ w3 + b3 # (B, 10) <== (B, 128) @ (128, 10)
    y_proba = softmax(logits) # (B, 10)
    loss = CrossEntropy(y, y_proba) # ()

    params = [w1, b1, gamma1, beta1, w2, b2, gamma2, beta2, w3, b3]
    # activations = [z1, h1, bnh1, z2, h2, bnh2, logits]
    return loss, y_proba, params #, activations

# %% [markdown]
# ### BackPropagation
# * Skipping this as you are a BackpropWhiz! (See nn.ipynb for that if you haven't)

# %% [markdown]
# ### Gradient Descent

# %%
def zero_grads(params:list[Tensor]):
    for param in params:
        param.grad = None

def sgd(lr:float, params:list[Tensor]):
    """returns updated `params` (parameters)"""
    for param in params:
        param.data -= lr * param.grad
    return params

# %% [markdown]
# ### Train Loop

# %%
def get_accuracy(y_true:Tensor, y_probs:Tensor):
    y_pred = torch.argmax(y_probs, axis=-1).cpu()
    return (y_true.cpu()==y_pred).float().sum()/len(y_true)

# %%
def train_loop(
        lr,
        epochs,
        train_ds, 
        val_ds,
        batch_size = 32,
        val_interval = 2
    ):
    X_train, y_train = train_ds
    XB_train, yB_train = batch(X_train, y_train, batch_size); m_B = XB_train.shape[0]
    X_val, y_val = val_ds
    
    # initialize parameters
    size = [784, 512, 128, 10]
    params = initialize_params(size)

    # For loop for epochs and steps
    plotlosses = []; t0 = time.time()
    for epoch in range(epochs):
        print(f"Epoch: {epoch+1}/{epochs}", end=" | ")
        losses = 0
        XB_train, yB_train = shuffle(XB_train, yB_train)
        for step in range(m_B):
            # Get batch
            X_batch, y_batch = XB_train[step].to(DEVICE), yB_train[step].to(DEVICE)
            # Forward pass
            loss, y_proba, params = forwardprop(
                X_batch, y_batch, params
            ); losses += loss
            # Zero grads
            zero_grads(params)
            # Backward pass
            loss.backward()
            # Update params
            params = sgd(lr, params)
            # list of losses for plotting
            plotlosses.append(loss.item())
        # time
        t1 = time.time()
        dt = t1 - t0; t0 = t1
        print(f"Loss: {(losses/m_B):.4f}", end=f" | Avg time per step: {(dt*1000/m_B):.2f} ms | ")
        print(f"Validation Loss: {forwardprop(X_val, y_val, params)[0]:.4f} |" if (epoch%val_interval==0 or epoch==epochs-1) else "")
    
    print(f"Train Accuracy:      {get_accuracy(y_train, forwardprop(X_train, y_train, params)[1]):.4f} |")
    print(f"Validation Accuracy: {get_accuracy(y_val, forwardprop(X_val, y_val, params)[1]):.4f} |")
    return params, plotlosses

# %%
params, losses = train_loop(0.01, 30, [X_train, y_train], [X_val, y_val], val_interval=1)
plt.plot(losses)
plt.xlabel("Steps")
plt.ylabel("Loss")
plt.title("`layernorm.ipynb.ipynb`")
plt.show()
# Out:
# Number of parameters in the network: 470154
# Epoch: 1/30 | Loss: 0.2805 | Avg time per step: 0.77 ms | Validation Loss: 0.1517 |
# Epoch: 2/30 | Loss: 0.1263 | Avg time per step: 0.73 ms | Validation Loss: 0.1156 |
# Epoch: 3/30 | Loss: 0.0877 | Avg time per step: 0.73 ms | Validation Loss: 0.0994 |
# Epoch: 4/30 | Loss: 0.0645 | Avg time per step: 0.73 ms | Validation Loss: 0.0918 |
# Epoch: 5/30 | Loss: 0.0481 | Avg time per step: 0.72 ms | Validation Loss: 0.0831 |
# Epoch: 6/30 | Loss: 0.0368 | Avg time per step: 0.73 ms | Validation Loss: 0.0801 |
# Epoch: 7/30 | Loss: 0.0278 | Avg time per step: 0.73 ms | Validation Loss: 0.0804 |
# Epoch: 8/30 | Loss: 0.0211 | Avg time per step: 0.73 ms | Validation Loss: 0.0792 |
# Epoch: 9/30 | Loss: 0.0162 | Avg time per step: 0.73 ms | Validation Loss: 0.0796 |
# Epoch: 10/30 | Loss: 0.0124 | Avg time per step: 0.72 ms | Validation Loss: 0.0788 |
# Epoch: 11/30 | Loss: 0.0096 | Avg time per step: 0.73 ms | Validation Loss: 0.0790 |
# Epoch: 12/30 | Loss: 0.0076 | Avg time per step: 0.72 ms | Validation Loss: 0.0778 |
# Epoch: 13/30 | Loss: 0.0061 | Avg time per step: 0.73 ms | Validation Loss: 0.0785 |
# Epoch: 14/30 | Loss: 0.0050 | Avg time per step: 0.73 ms | Validation Loss: 0.0772 |
# Epoch: 15/30 | Loss: 0.0042 | Avg time per step: 0.72 ms | Validation Loss: 0.0778 |
# Epoch: 16/30 | Loss: 0.0036 | Avg time per step: 0.73 ms | Validation Loss: 0.0790 |
# Epoch: 17/30 | Loss: 0.0031 | Avg time per step: 0.73 ms | Validation Loss: 0.0787 |
# Epoch: 18/30 | Loss: 0.0028 | Avg time per step: 0.73 ms | Validation Loss: 0.0789 |
# Epoch: 19/30 | Loss: 0.0025 | Avg time per step: 0.73 ms | Validation Loss: 0.0795 |
# Epoch: 20/30 | Loss: 0.0022 | Avg time per step: 0.72 ms | Validation Loss: 0.0798 |
# Epoch: 21/30 | Loss: 0.0020 | Avg time per step: 0.73 ms | Validation Loss: 0.0799 |
# Epoch: 22/30 | Loss: 0.0019 | Avg time per step: 0.73 ms | Validation Loss: 0.0803 |
# Epoch: 23/30 | Loss: 0.0017 | Avg time per step: 0.72 ms | Validation Loss: 0.0806 |
# Epoch: 24/30 | Loss: 0.0016 | Avg time per step: 0.72 ms | Validation Loss: 0.0808 |
# Epoch: 25/30 | Loss: 0.0015 | Avg time per step: 0.73 ms | Validation Loss: 0.0810 |
# Epoch: 26/30 | Loss: 0.0014 | Avg time per step: 0.72 ms | Validation Loss: 0.0818 |
# Epoch: 27/30 | Loss: 0.0013 | Avg time per step: 0.72 ms | Validation Loss: 0.0813 |
# Epoch: 28/30 | Loss: 0.0012 | Avg time per step: 0.73 ms | Validation Loss: 0.0820 |
# Epoch: 29/30 | Loss: 0.0012 | Avg time per step: 0.72 ms | Validation Loss: 0.0827 |
# Epoch: 30/30 | Loss: 0.0011 | Avg time per step: 0.72 ms | Validation Loss: 0.0826 |
# Train Accuracy:      1.0000 |
# Validation Accuracy: 0.9788 |

# %% [markdown]
# * Step at which we get the best Val Loss:
#
#   `Epoch: 14/30 | Loss: 0.0050 | Avg time per step: 0.73 ms | Validation Loss: 0.0772 |`

# %% [markdown]
# ## Make Predictions

# %%
def predict(img_idx):
    img = torch.tensor(X_VAL[img_idx].tolist())[0] # (28, 28)
    y_true = y_val[img_idx].cpu()
    plt.imshow(img, cmap='gray')
    plt.axis('off')

    y_pred = torch.argmax(forwardprop(img.reshape((1, -1)), y_true, params)[1], axis=-1).cpu()
    print(f"True Digit: {y_true}")
    print(f"Predicted Digit: {y_pred}")
    plt.show()

# %%
for _ in range(100):
    predict(torch.randint(10_000, (1,)))
# Out:
# True Digit: tensor([6])
# Predicted Digit: tensor([6])
# True Digit: tensor([3])
# Predicted Digit: tensor([3])
# True Digit: tensor([9])
# Predicted Digit: tensor([9])
# True Digit: tensor([1])
# Predicted Digit: tensor([1])
# True Digit: tensor([7])
# Predicted Digit: tensor([7])
# True Digit: tensor([0])
# Predicted Digit: tensor([0])
# True Digit: tensor([2])
# Predicted Digit: tensor([2])
# True Digit: tensor([0])
# Predicted Digit: tensor([0])
# True Digit: tensor([3])
# Predicted Digit: tensor([3])
# True Digit: tensor([5])
# Predicted Digit: tensor([5])
# True Digit: tensor([3])
# Predicted Digit: tensor([3])
# True Digit: tensor([3])
# Predicted Digit: tensor([3])
# True Digit: tensor([8])
# Predicted Digit: tensor([8])
# True Digit: tensor([4])
# Predicted Digit: tensor([4])
# True Digit: tensor([0])
# Predicted Digit: tensor([0])
# True Digit: tensor([4])
# Predicted Digit: tensor([4])
# True Digit: tensor([8])
# Predicted Digit: tensor([8])
# True Digit: tensor([7])
# Predicted Digit: tensor([7])
# True Digit: tensor([4])
# Predicted Digit: tensor([4])
# True Digit: tensor([2])
# Predicted Digit: tensor([2])
# True Digit: tensor([2])
# Predicted Digit: tensor([2])
# True Digit: tensor([1])
# Predicted Digit: tensor([1])
# True Digit: tensor([1])
# Predicted Digit: tensor([1])
# True Digit: tensor([0])
# Predicted Digit: tensor([0])
# True Digit: tensor([2])
# Predicted Digit: tensor([2])
# True Digit: tensor([2])
# Predicted Digit: tensor([2])
# True Digit: tensor([0])
# Predicted Digit: tensor([0])
# True Digit: tensor([0])
# Predicted Digit: tensor([0])
# True Digit: tensor([1])
# Predicted Digit: tensor([1])
# True Digit: tensor([5])
# Predicted Digit: tensor([5])
# True Digit: tensor([3])
# Predicted Digit: tensor([3])
# True Digit: tensor([5])
# Predicted Digit: tensor([5])
# True Digit: tensor([1])
# Predicted Digit: tensor([1])
# True Digit: tensor([6])
# Predicted Digit: tensor([6])
# True Digit: tensor([2])
# Predicted Digit: tensor([2])
# True Digit: tensor([7])
# Predicted Digit: tensor([7])
# True Digit: tensor([7])
# Predicted Digit: tensor([7])
# True Digit: tensor([1])
# Predicted Digit: tensor([1])
# True Digit: tensor([6])
# Predicted Digit: tensor([6])
# True Digit: tensor([8])
# Predicted Digit: tensor([8])
# True Digit: tensor([1])
# Predicted Digit: tensor([1])
# True Digit: tensor([6])
# Predicted Digit: tensor([6])
# True Digit: tensor([8])
# Predicted Digit: tensor([8])
# True Digit: tensor([9])
# Predicted Digit: tensor([9])
# True Digit: tensor([6])
# Predicted Digit: tensor([6])
# True Digit: tensor([1])
# Predicted Digit: tensor([1])
# True Digit: tensor([2])
# Predicted Digit: tensor([2])
# True Digit: tensor([7])
# Predicted Digit: tensor([7])
# True Digit: tensor([2])
# Predicted Digit: tensor([2])
# True Digit: tensor([4])
# Predicted Digit: tensor([4])
# True Digit: tensor([3])
# Predicted Digit: tensor([3])
# True Digit: tensor([7])
# Predicted Digit: tensor([7])
# True Digit: tensor([3])
# Predicted Digit: tensor([3])
# True Digit: tensor([7])
# Predicted Digit: tensor([7])
# True Digit: tensor([2])
# Predicted Digit: tensor([2])
# True Digit: tensor([1])
# Predicted Digit: tensor([1])
# True Digit: tensor([7])
# Predicted Digit: tensor([7])
# True Digit: tensor([1])
# Predicted Digit: tensor([1])
# True Digit: tensor([7])
# Predicted Digit: tensor([7])
# True Digit: tensor([8])
# Predicted Digit: tensor([8])
# True Digit: tensor([1])
# Predicted Digit: tensor([1])
# True Digit: tensor([7])
# Predicted Digit: tensor([7])
# True Digit: tensor([6])
# Predicted Digit: tensor([6])
# True Digit: tensor([2])
# Predicted Digit: tensor([2])
# True Digit: tensor([6])
# Predicted Digit: tensor([6])
# True Digit: tensor([1])
# Predicted Digit: tensor([1])
# True Digit: tensor([4])
# Predicted Digit: tensor([4])
# True Digit: tensor([6])
# Predicted Digit: tensor([6])
# True Digit: tensor([7])
# Predicted Digit: tensor([7])
# True Digit: tensor([4])
# Predicted Digit: tensor([4])
# True Digit: tensor([0])
# Predicted Digit: tensor([0])
# True Digit: tensor([3])
# Predicted Digit: tensor([3])
# True Digit: tensor([4])
# Predicted Digit: tensor([4])
# True Digit: tensor([8])
# Predicted Digit: tensor([8])
# True Digit: tensor([6])
# Predicted Digit: tensor([6])
# True Digit: tensor([7])
# Predicted Digit: tensor([7])
# True Digit: tensor([1])
# Predicted Digit: tensor([1])
# True Digit: tensor([6])
# Predicted Digit: tensor([6])
# True Digit: tensor([4])
# Predicted Digit: tensor([4])
# True Digit: tensor([9])
# Predicted Digit: tensor([9])
# True Digit: tensor([5])
# Predicted Digit: tensor([5])
# True Digit: tensor([4])
# Predicted Digit: tensor([4])
# True Digit: tensor([0])
# Predicted Digit: tensor([0])
# True Digit: tensor([1])
# Predicted Digit: tensor([1])
# True Digit: tensor([4])
# Predicted Digit: tensor([4])
# True Digit: tensor([7])
# Predicted Digit: tensor([7])
# True Digit: tensor([1])
# Predicted Digit: tensor([1])
# True Digit: tensor([9])
# Predicted Digit: tensor([9])
# True Digit: tensor([3])
# Predicted Digit: tensor([3])
# True Digit: tensor([9])
# Predicted Digit: tensor([9])
# True Digit: tensor([3])
# Predicted Digit: tensor([3])
# True Digit: tensor([3])
# Predicted Digit: tensor([3])
# True Digit: tensor([9])
# Predicted Digit: tensor([9])
# True Digit: tensor([3])
# Predicted Digit: tensor([3])
# True Digit: tensor([7])
# Predicted Digit: tensor([7])
# True Digit: tensor([1])
# Predicted Digit: tensor([1])
# True Digit: tensor([8])
# Predicted Digit: tensor([8])
# True Digit: tensor([2])
# Predicted Digit: tensor([2])
# True Digit: tensor([1])
# Predicted Digit: tensor([1])
# True Digit: tensor([1])
# Predicted Digit: tensor([1])
